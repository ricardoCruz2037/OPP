# %% [markdown]
# ## Diccionarios
# A diferencia de las listas se declaran con las llaves:  dic = {}, los diccionarios llevan claves, palabra clave separada por dos puntos: dic = {'Nombre': 'Richi'}

# %%
dic = {'Nombre': 'Richi', 'Edad': 19,'Altura': 1.65}
print(dic)
# Out:
# {'Nombre': 'Richi', 'Edad': 19, 'Altura': 1.65}

# %% [markdown]
# Hay momentos donde en un for no quiere accesar a con un indice para recorrer uno por uno

# %%
list = [2, 3, -5, 4]
print(list)

for valor in list:
    print(valor)
# Out:
# [2, 3, -5, 4]
# 2
# 3
# -5
# 4

# %% [markdown]
# Y como recorro un diccionario?

# %%
dic = {'Nombre': 'Richi', 'Edad': 19,'Altura': 1.65}
print('Dic', dic,'\n')

# Al recorrer diccionario
for valor in dic:
    print(valor)
    
print('\n')
# Al recorrer keys
for valor in dic.keys():
    print(valor)
    
print('\n')

# Al recorrer values
for valor in dic.values():
    print(valor)
    
# Imprimir key en especifico
print('\n',dic['Nombre'])

# Imprimir propiedades
print(dir(dic))

# Imprimir Help
print('\n',help(dic))

# Regresa una túpla de objetos
print('\n',dic.items(),'\n')

# Items, ambos
for valor in dic.items():
    print(valor)

print('\n')
    
# keys y valores
for key, valor in dic.items():
    print(key, valor)

dic['Nombre'] = 'Dan'
print(dic)
# Out:
# Dic {'Nombre': 'Richi', 'Edad': 19, 'Altura': 1.65}
#
# Nombre
# Edad
# Altura
#
#
# Nombre
# Edad
# Altura
#
#
# Richi
# 19
# 1.65
#
#  Richi
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']
# Help on dict object:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
# ...

# %% [markdown]
# En una lista le pasas el numero de indice, en un diccionario le pasas la key!
